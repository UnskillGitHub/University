# %% [markdown]
# <a href="https://colab.research.google.com/github/UnskillGitHub/University/blob/main/Tasks/First_Programm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('Hello world')
print('Hi, Seversk')
# Out:
# Hello world
# Hi, Seversk
